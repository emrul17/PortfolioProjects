# %% [markdown]
# # Salary Predictions Based on Job Descriptions

# %% [markdown]
# ### ---- 1 Define the problem ----

# %% [markdown]
# The task is to examine a set of job postings with salaries and then predict salaries for a new set of job postings.

# %%
# Basic data analysis libraries
import pandas as pd
import sklearn as sk
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Personal Information
__author__ = "Emrul Hasan"
__email__ = "emrul.phy@gmail.com"

# %% [markdown]
# ## Part 2 - DISCOVER

# %%
def load_data(df):
    return pd.read_csv(df)

train_data=load_data('train_features.csv')
test_data=load_data('test_features.csv')
salary_data=load_data('train_salaries.csv')

# %%
# Print basic information about the data

def data_info(df):
    

    print('Shape of the data: ', df.shape)
    
    print('------------########################------------------')
    print('\nInformation of the data:\n', df.info())
    
    print('------------########################------------------')
    print('Check the duplication of the data:', df.duplicated().sum())
    print('------------########################------------------')
    print('\nCheck the missing value of the data:\n', df.isnull().sum())

# %%
data_info(train_data)
# Out:
# Shape of the data:  (1000000, 8)
# ------------########################------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 8 columns):
# jobId                  1000000 non-null object
# companyId              1000000 non-null object
# jobType                1000000 non-null object
# degree                 1000000 non-null object
# major                  1000000 non-null object
# industry               1000000 non-null object
# yearsExperience        1000000 non-null int64
# milesFromMetropolis    1000000 non-null int64
# dtypes: int64(2), object(6)
# memory usage: 61.0+ MB
#
# Information of the data:
#  None
# ------------########################------------------
# Check the duplication of the data: 0
# ------------########################------------------
#
# Check the missing value of the data:
#  jobId                  0
# companyId              0
# jobType                0
# degree                 0
# ...

# %% [markdown]
# Here we have total three datasets, train data, test data and salary or target data. We need to preprocess both train and test data. Because, evaluating the model we need to make clean the test data as well. So I am going to add both train and test data so that all the dataset are being cleaned at a time. After cleaning the data, we will separate the test data. Before that, lets, merge the train and target data

# %%
# Adding the target column with the training dataset
def full_data(df1,df2,key=None ):
    return pd.merge(df1, df2,on=key)

train=full_data(train_data, salary_data,key='jobId')

# %% [markdown]
# #
# From the info, we can see there are total of 1000000 rows and 9 columns. Also it tell us data types are integer and object

# %% [markdown]
# ### ---- 3 Clean the data ----

# %% [markdown]
# Identify numerical and categorical data and Summaries categorical and numerical variables separately

# %%
def summary(df):
    print('\nSummary of Numberical data:\n', df.describe(include=np.number))
    print('------------########################------------------')
    print('\nSummary of categorical data:\n',df.describe(include='O'))
     

#train_data.describe(include=np.number)

# %%
summary(train)
# Out:
# Summary of Numberical data:
#         yearsExperience  milesFromMetropolis          salary
# count   1000000.000000       1000000.000000  1000000.000000
# mean         11.992386            49.529260      116.061818
# std           7.212391            28.877733       38.717936
# min           0.000000             0.000000        0.000000
# 25%           6.000000            25.000000       88.000000
# 50%          12.000000            50.000000      114.000000
# 75%          18.000000            75.000000      141.000000
# max          24.000000            99.000000      301.000000
# ------------########################------------------
#
# Summary of categorical data:
#                     jobId companyId  jobType       degree    major industry
# count            1000000   1000000  1000000      1000000  1000000  1000000
# unique           1000000        63        8            5        9        7
# top     JOB1362684897469    COMP39   SENIOR  HIGH_SCHOOL     NONE      WEB
# ...

# %% [markdown]
# Visualize the target variable

# %%
def plot_target(df):
    plt.figure(figsize=(14,6))
    plt.subplot(1,2,1)
    sns.boxplot(df.salary)

    plt.subplot(1,2,2)
    sns.distplot(df.salary, bins=20)
    plt.show()

# %%
plot_target(train)
# Out:
# C:\Users\T420\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# It is clear that there are outliers. Furhter analysis would guide us how to tackle these outliers. There can be many reasons for outliers. It can be incorrectly reported or some unsual data. Further examination is required to find the actual reason behind the outlier

# %% [markdown]
# Identify lower and uppor bound of the outlier

# %%
def outlier(df):
    stat=df.describe()
    IQR=stat['75%']-stat['25%']
    upper=stat['75%']+1.5*IQR
    lower=stat['25%']-1.5*IQR
    print('The upper and lower bounds for outliers are {} and {}'.format(upper,lower))

# %%
outlier(train.salary)
# Out:
# The upper and lower bounds for outliers are 220.5 and 8.5

# %% [markdown]
# Examine the outliers

# %%
# check the potential suspicious outliers below the lower boun
train[train.salary<8.5]
# Out:
#                    jobId companyId         jobType       degree        major  \
# 30559   JOB1362684438246    COMP44          JUNIOR     DOCTORAL         MATH
# 495984  JOB1362684903671    COMP34          JUNIOR         NONE         NONE
# 652076  JOB1362685059763    COMP25             CTO  HIGH_SCHOOL         NONE
# 816129  JOB1362685223816    COMP42         MANAGER     DOCTORAL  ENGINEERING
# 828156  JOB1362685235843    COMP40  VICE_PRESIDENT      MASTERS  ENGINEERING
#
#        industry  yearsExperience  milesFromMetropolis  salary
# 30559      AUTO               11                    7       0
# 495984      OIL                1                   25       0
# 652076     AUTO                6                   60       0
# 816129  FINANCE               18                    6       0
# 828156      WEB                3                   29       0

# %%
outliers_low=train[train.salary<8.5]
outliers_up=train[train.salary>220.5]
# number of outliers
train.loc[train.salary>220.5,'jobType'].value_counts()
# Out:
# CEO               3227
# CFO               1496
# CTO               1488
# VICE_PRESIDENT     603
# MANAGER            217
# SENIOR              66
# JUNIOR              20
# Name: jobType, dtype: int64

# %%
outliers_up
# Out:
#                    jobId companyId         jobType       degree        major  \
# 266     JOB1362684407953    COMP30             CEO      MASTERS      BIOLOGY
# 362     JOB1362684408049    COMP38             CTO      MASTERS         NONE
# 560     JOB1362684408247    COMP53             CEO      MASTERS      BIOLOGY
# 670     JOB1362684408357    COMP26             CEO      MASTERS         MATH
# 719     JOB1362684408406    COMP54  VICE_PRESIDENT     DOCTORAL      BIOLOGY
# 966     JOB1362684408653    COMP32             CEO     DOCTORAL  ENGINEERING
# 986     JOB1362684408673    COMP37             CFO  HIGH_SCHOOL         NONE
# 1211    JOB1362684408898    COMP24             CTO     DOCTORAL     BUSINESS
# 1222    JOB1362684408909    COMP40          JUNIOR      MASTERS      COMPSCI
# 1413    JOB1362684409100    COMP56  VICE_PRESIDENT      MASTERS         MATH
# 1500    JOB1362684409187    COMP40             CTO    BACHELORS      PHYSICS
# ...

# %% [markdown]
# That's quite lot. We need further analysis to check if they are really outliers or not. If we take a close look at the data it is found that junior position is also paid above that outlier. So look at them.

# %%
# check the potential suspicious outliers above the upper bound
train[(train.salary>220.5) & (train_data.jobType=='JUNIOR')]
# Out:
#                    jobId companyId jobType     degree        major industry  \
# 1222    JOB1362684408909    COMP40  JUNIOR    MASTERS      COMPSCI      OIL
# 27710   JOB1362684435397    COMP21  JUNIOR   DOCTORAL  ENGINEERING      OIL
# 31355   JOB1362684439042    COMP45  JUNIOR   DOCTORAL      COMPSCI  FINANCE
# 100042  JOB1362684507729    COMP17  JUNIOR   DOCTORAL     BUSINESS  FINANCE
# 160333  JOB1362684568020    COMP18  JUNIOR   DOCTORAL     BUSINESS  FINANCE
# 189582  JOB1362684597269    COMP32  JUNIOR   DOCTORAL     BUSINESS      OIL
# 214606  JOB1362684622293    COMP47  JUNIOR    MASTERS     BUSINESS  FINANCE
# 303778  JOB1362684711465    COMP51  JUNIOR    MASTERS  ENGINEERING      WEB
# 348354  JOB1362684756041    COMP56  JUNIOR   DOCTORAL  ENGINEERING      OIL
# 427593  JOB1362684835280    COMP54  JUNIOR   DOCTORAL  ENGINEERING  FINANCE
# 500739  JOB1362684908426    COMP40  JUNIOR   DOCTORAL  ENGINEERING      OIL
# ...

# %% [markdown]
# These entries with zero salary are not realistic. We are confident that these are missing or corupted data and should be removed from training data set.
#
# The high salary potential outliers appear to be legitimate data. Most of the roles are c-level junior position. As it is seen that the employes have advanced degrees and the companies like oil and finance well known for high salaries, it is expected the the data are realistics

# %% [markdown]
# ### ---- 4 Explore the data (EDA) ----

# %%
#summarize each feature variable
#summarize the target variable
#look for correlation between each feature and the target
#look for correlation between features

# remove the data with zero salaries
train=train[train.salary>8.5]

# %%
train.head()
# Out:
#               jobId companyId         jobType       degree      major  \
# 0  JOB1362684407687    COMP37             CFO      MASTERS       MATH
# 1  JOB1362684407688    COMP19             CEO  HIGH_SCHOOL       NONE
# 2  JOB1362684407689    COMP52  VICE_PRESIDENT     DOCTORAL    PHYSICS
# 3  JOB1362684407690    COMP38         MANAGER     DOCTORAL  CHEMISTRY
# 4  JOB1362684407691     COMP7  VICE_PRESIDENT    BACHELORS    PHYSICS
#
#   industry  yearsExperience  milesFromMetropolis  salary
# 0   HEALTH               10                   83     130
# 1      WEB                3                   73     101
# 2   HEALTH               10                   38     137
# 3     AUTO                8                   17     142
# 4  FINANCE                8                   16     163

# %%
cat_col=['jobType', 'degree', 'major', 'industry']
num_col= ['yearsExperience', 'milesFromMetropolis']

# %%
def plot_feature(df):
    #cat_col=list(new_df.columns)
    for col in cat_col:
        f, ax = plt.subplots(figsize=(8, 6))
        sns.boxplot(x=col,y='salary', data=df)

# %%
plot_feature(train)

# %% [markdown]
# # Converting categorical data into numerical data
# There are two different ways of converting categorical data. One hot encoding and label encoding: For detail: https://medium.com/@contactsunny/label-encoder-vs-one-hot-encoder-in-machine-learning-3fc273365621

# %% [markdown]
# Before converting the data let's remove the jobId columns becuase job id is different for different entry that's not making any changes for our prediction

# %%
train=train.drop(columns=['jobId'])
train.head()
# Out:
#   companyId         jobType       degree      major industry  yearsExperience  \
# 0    COMP37             CFO      MASTERS       MATH   HEALTH               10
# 1    COMP19             CEO  HIGH_SCHOOL       NONE      WEB                3
# 2    COMP52  VICE_PRESIDENT     DOCTORAL    PHYSICS   HEALTH               10
# 3    COMP38         MANAGER     DOCTORAL  CHEMISTRY     AUTO                8
# 4     COMP7  VICE_PRESIDENT    BACHELORS    PHYSICS  FINANCE                8
#
#    milesFromMetropolis  salary
# 0                   83     130
# 1                   73     101
# 2                   38     137
# 3                   17     142
# 4                   16     163

# %%
clean_data=pd.get_dummies(train, columns=['companyId','jobType','degree','major','industry'])

# %%
#clean_data=clean_data.drop(columns=['companyId'])
clean_data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-52c4adb5576d> in <module>()
# ----> 1 clean_data=clean_data.drop(columns=['companyId'])
#       2 clean_data.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3692                                            index=index, columns=columns,
#    3693                                            level=level, inplace=inplace,
# -> 3694                                            errors=errors)
#    3695
#    3696     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3106         for axis, labels in axes.items():
#    3107             if labels is not None:
# ...

# %% [markdown]
# ### ---- 5 Establish a baseline ----

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test=train_test_split(X,Y, test_size=0.3, random_state=42 )

# Separate test features and target column
#X_train=clean_data.drop(columns=['salary'])
#Y_train=clean_data['salary']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-0a55085212b3> in <module>()
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train,X_test, y_train,y_test=train_test_split(X,Y, test_size=0.3, random_state=42 )
#       3
#       4 # Separate test features and target column
#       5 #X_train=clean_data.drop(columns=['salary'])
#
# NameError: name 'X' is not defined

# %%
# import linear regression model
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

# linear regression model
LinReg=LinearRegression()
# fit model
LinReg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
score=LinReg.score(X_train,y_train)
print('Training score {}'.format(score))

print('Test score {}'.format(LinReg.score(X_test,y_test)))
# Out:
# Training score 1.0
# Test score 1.0

# %% [markdown]
# # Cross validation score

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val=cross_val_score(LinReg,X_train,Y_train, cv=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-17ebe2d558cd> in <module>()
# ----> 1 cross_val=cross_val_score(LinReg,X_train,Y_train, cv=5)
#
# NameError: name 'Y_train' is not defined

# %%
cross_val.mean()

# %%
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### ---- 6 Hypothesize solution ----

# %%
#brainstorm 3 models that you think may improve results over the baseline model based
#on your 
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

RanForest=RandomForestRegressor()
GradBoost=GradientBoostingRegressor()


RanForest.fit(X_train,Y_train)
GradBoost.fit(X_train,Y_train)

Ran_Score=RanForest.score(X_train,Y_train)
GradBScore=GradBoost.score(X_train,Y_train)

# %%
Ran_Score

# %%
GradBScore

# %% [markdown]
# Brainstorm 3 models that you think may improve results over the baseline model based on your EDA and explain why they're reasonable solutions here.
#
# Also write down any new features that you think you should try adding to the model based on your EDA, e.g. interaction variables, summary statistics for each group, etc

# %% [markdown]
# ## Part 3 - DEVELOP

# %% [markdown]
# You will cycle through creating features, tuning models, and training/validing models (steps 7-9) until you've reached your efficacy goal
#
# #### Your metric will be MSE and your goal is:
#  - <360 for entry-level data science roles
#  - <320 for senior data science roles

# %% [markdown]
# ### ---- 7 Engineer features  ----

# %%
#make sure that data is ready for modeling
#create any new features needed to potentially enhance model

# %% [markdown]
# ### ---- 8 Create models ----

# %%
#create and tune the models that you brainstormed during part 2

# %% [markdown]
# ### ---- 9 Test models ----

# %%
#do 5-fold cross validation on models and measure MSE

# %% [markdown]
# ### ---- 10 Select best model  ----

# %%
#select the model with the lowest error as your "prodcuction" model

# %% [markdown]
# ## Part 4 - DEPLOY

# %% [markdown]
# ### ---- 11 Automate pipeline ----

# %%
#write script that trains model on entire training set, saves model to disk,
#and scores the "test" dataset

# %% [markdown]
# ### ---- 12 Deploy solution ----

# %%
#save your prediction to a csv file or optionally save them as a table in a SQL database
#additionally, you want to save a visualization and summary of your prediction and feature importances
#these visualizations and summaries will be extremely useful to business stakeholders

# %% [markdown]
# ### ---- 13 Measure efficacy ----

# %% [markdown]
# We'll skip this step since we don't have the outcomes for the test data

# %%
cross_val_score()
